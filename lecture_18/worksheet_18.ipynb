# %% [markdown]
# # Worksheet 18
#
# Name:  Prathmesh Sonawane
#
# UID: U39215370
#
# ### Topics
#
# - Linear Regression
#
# ### Optional Challenge
#
# Every day my alarm goes off at seemingly random times… I’ve recorded the times at which it goes off for the past year of so (1 - 355 days). Today is day 356. Can you predict when my alarm will ring using `data.csv`?
#
# Please fill out the piazza poll if you think you found the answer.
#
# ## Linear Regression
#
# Where does randomness come from?

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

SAMPLE_SIZE = 100

# it's possible for y = 3 * x_1 + (1/4) * x_2
# but we don't know to look for x_2 and we only have x_1 as a feature
x1 = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
x2 = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
y = 3 * x1 + (1/4) * x2

# Create the figure
fig = plt.figure()

# Add an axes
ax = fig.add_subplot(111,projection='3d')

# and plot the point 
ax.scatter(x1 , x2 , y,  color='green')
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_zlabel("y")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# a) Create and plot a dataset of 100 (Y, X) points where `Y = 1 + 0.5 * X + eps`.

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 100

ax = plt.figure().subplots()

true_beta = np.array([ 1 , 0.5])
#Needed to make X larger so we actually see the linear relationship better. 
x = -10 + 20 * np.random.random(SAMPLE_SIZE)
y = true_beta[0] + true_beta[1] * x + np.random.randn(SAMPLE_SIZE)

#Set Axis Limits
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
plt.plot(x,y,'ro',markersize=4)
plt.show()
# Out:
# /var/folders/fb/7pj1rlw106df8gw1btlbdhxc0000gn/T/ipykernel_77806/523499469.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   ax = plt.figure().subplots()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# b) Plot the least squares estimate line through the scatter plot.

# %%
bx = plt.figure().subplots()

intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

x_plot = np.linspace(-10,10,50)
y_est = beta_hat[0] + beta_hat[1] * x_plot
plt.plot(x_plot, y_est,'b--', lw=2, label='Estimate')
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot, lw=2, c='g', label='Truth')
plt.plot(x, y,'ro',markersize=4)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# c) How does the estimate of `beta` compare to the parameters we used to generate the data?

# %%
print([beta_hat])
# Out:
# [array([0.9582888 , 0.48998792])]

# %% [markdown]
# Our original beta was [1,0.5]. When we print our estimate/predicition, we get [0.96,0.49], which is pretty close to our initial beta.

# %% [markdown]
# d) Create and plot a dataset of 100 (Y, X) points where `Y = 1 + 3 * X + .5 * X^2 + eps`.

# %%
#Coppied from the top
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 100

cx = plt.figure().subplots()

true_beta = np.array([ 1 , 3, 0.5])
#Needed to make X larger so we actually see the linear relationship better. 
x = -10 + 20 * np.random.random(SAMPLE_SIZE)
y = true_beta[0] + true_beta[1] * x + (true_beta[2] * x**2) + np.random.randn(SAMPLE_SIZE)

#Set Axis Limits
cx.set_xlim(-10, 10)
cx.set_ylim(-10, 10)
plt.plot(x,y,'ro',markersize=4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# e) Plot the least squares estimate line through the scatter plot.

# %%
cx = plt.figure().subplots()

intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x, x **2]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

x_plot = np.linspace(-10,10,50)
y_est = beta_hat[0] + beta_hat[1] * x_plot + beta_hat[2] * (x_plot ** 2)
plt.plot(x_plot, y_est,'b--', lw=2, label='Estimate')
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot + true_beta[2] * (x_plot ** 2), lw=2, c='g', label='Truth')
plt.plot(x, y,'ro',markersize=4)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# f) How does the estimate of `beta` compare to the parameters we used to generate the data?

# %%
print([beta_hat])
# Out:
# [array([0.83929279, 3.02228107, 0.49997761])]

# %% [markdown]
# Our original beta was [1,3,0.5]. When we print our estimate/predicition, we get [0.84,3.02, 0.5], which is also pretty close to our initial beta.

# %% [markdown]
# g) Let's repeat d) and f) a large number of times to see how close our estimates are on average and what that distribution looks like.

# %%
#Lets do D First
fx = plt.figure().subplots()

SAMPLE_SIZE = 10000

betas = []
true_beta = np.array([1, 0.5])
for _ in range(10000):
    x = -1 + 2 * np.random.random(SAMPLE_SIZE)
    y = true_beta[0] + true_beta[1] * x + np.random.randn(SAMPLE_SIZE)
    intercept = np.ones(np.shape(x)[0])
    X = np.array([intercept, x]).T
    betas.append(np.linalg.inv(X.T @ X) @ X.T @ y)

plt.title("Y = 1 + 0.5X")
plt.xlabel("Value of β")
plt.hist(np.array(betas)[:, 1], bins=100)
plt.axvline(x=true_beta[1], c='r', linestyle='dashed')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Now F 
import numpy as np
import matplotlib.pyplot as plt

gx = plt.figure().subplots()

SAMPLE_SIZE = 10000

betas = []
true_beta = np.array([1, 3, 0.5])
for _ in range(10000):
    x = -1 + 2 * np.random.random(SAMPLE_SIZE)
    y = true_beta[0] + true_beta[1] * x + true_beta[2] * (x ** 2) + np.random.randn(SAMPLE_SIZE)
    intercept = np.ones(np.shape(x)[0])
    X = np.array([intercept, x, x ** 2]).T
    betas.append(np.linalg.inv(X.T @ X) @ X.T @ y)

plt.title("Y = 1 + 3X + 0.5X^2")
plt.xlabel("Value of β")
plt.hist(np.array(betas)[:, 1], bins=100)
plt.axvline(x=true_beta[1], c='r', linestyle='dashed')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
